# %%
# Exp1 : Introduction to python
#Lakshya Sonawane

# %%
x,y,z = " apple" , "orange " , "cherry"
print(x,y,z,sep="\n")
# Out:
#  apple
# orange
# cherry

# %%
a , b ,c ,d = 2 , 2.5 , "Lakshya" , True
print(type(a),type(b),type(c),type(d),sep="\n")
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
a = 10
b = 5
print("add=",a+b,"sub=",a-b,"mul=",a*b,"div=",a/b,"exp=",a**b)
# Out:
# add= 15 sub= 5 mul= 50 div= 2.0 exp= 100000

# %%
a = int(input("Enter value for a: "))
b = int(input("Enter value for b: "))
print("add=",a+b,"\n","sub=",a-b,"\n","mul=",a*b,"\n","div=",a/b,"\n","exp=",a**b,"\n",)
# Out:
# Enter value for a: 5
# Enter value for b: 4
# add= 9
#  sub= 1
#  mul= 20
#  div= 1.25
#  exp= 625

# %%
import math
r =float(input("Enter radius: "))
Area=math.pi*r**2
print("Area of circle is: ",Area)
# Out:
# Enter radius: 6
# Area of circle is:  113.09733552923255

# %%
import math
print(math.log10(10))
# Out:
# 1.0

# %%
import math
a = math.pi/4
print(math.sin(a))
# Out:
# 0.7071067811865475

# %%
a = float(input("Enter a number: "))
b = float(input("Enter a number: "))
if a>b:
    print("b is less than a")
else:
    print("b is greater than a")
# Out:
# Enter a number: 5.5
# Enter a number: 6.5
# b is greater than a
